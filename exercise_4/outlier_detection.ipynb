# %%
import json
from pprint import pprint
data = open("ed_trade_data.json")
data = json.load(data)
len(data.keys())
#pprint (data)
# Out:
# 275

# %%
l1 = list(data.keys())
l1
# Out:
# [u'ETH_NEWB',
#  u'ETH_NTC',
#  u'ETH_LNK',
#  u'ETH_IXT',
#  u'ETH_ETHP',
#  u'ETH_SUB',
#  u'ETH_1ST',
#  u'ETH_ETHG',
#  u'ETH_ETHD',
#  u'ETH_BNN',
#  u'ETH_RLC',
#  u'ETH_SKIN',
#  u'ETH_BNB',
#  u'ETH_XNN',
#  u'ETH_SDRN',
#  u'ETH_KNC',
#  u'ETH_IND',
#  u'ETH_0x5046',
#  u'ETH_TAAS',
#  u'ETH_LUCK',
#  u'ETH_NIMFA',
#  u'ETH_PPP',
#  u'ETH_WTT',
#  u'ETH_PPT',
#  u'ETH_EBCSH',
#  u'ETH_NDC',
#  u'ETH_TOV',
#  u'ETH_CM',
#  u'ETH_0xe469',
#  u'ETH_CODE',
#  u'ETH_BTH2',
#  u'ETH_KEY',
#  u'ETH_DOM',
#  u'ETH_PGL',
#  u'ETH_0x5f6e',
#  u'ETH_ETL',
#  u'ETH_RVT',
#  u'ETH_TKR',
#  u'ETH_EGOLD',
#  u'ETH_MCAP',
#  u'ETH_DEL',
#  u'ETH_EDOGE',
#  u'ETH_SHIT',
#  u'ETH_VEN',
#  u'ETH_HGT',
#  u'ETH_SMT',
#  u'ETH_DET',
#  u'ETH_0x1245',
#  u'ETH_ACC',
#  u'ETH_AION',
#  u'ETH_BNT',
#  u'ETH_BQX',
#  u'ETH_CNX',
#  u'ETH_DNT',
#  u'ETH_BAT',
#  u'ETH_POE',
#  u'ETH_SALT',
#  u'ETH_BAS',
#  u'ETH_BCAP',
#  u'ETH_CCT',
#  u'ETH_FNL',
#  u'ETH_FYN',
#  u'ETH_0xd51e',
#  u'ETH_0x50d2',
# ...

# %%
import pandas as pd
x1 = data[l1[0]]
df1 = pd.DataFrame(x1)
df1
# Out:
#     amount            amountBase                                       buyer  \
# 0       14                0.0005  0x4fda9e6bcd83af6c5cc771b5d20accc2b7720074
# 1       14                0.0005  0x3075f7f189912f4f425dd7021b9c396434197477
# 2    11637             0.4247505  0x13e2c5f84bce6ff7b9068313b21729dc8fd55d5a
# 3      697              0.018819  0x13e2c5f84bce6ff7b9068313b21729dc8fd55d5a
# 4     2499              0.067473  0x13e2c5f84bce6ff7b9068313b21729dc8fd55d5a
# 5      700             0.0189021  0xafb7144110020e048d3272efc7213e6543772bb5
# 6       30               0.00108  0x0b773d7819259d78757b26dc4148812d35676d8f
# 7        0                     0  0xf36990a2cb4d609e0a7d4f3bf884c0342d81fd3d
# 8      947              0.025569  0x13e2c5f84bce6ff7b9068313b21729dc8fd55d5a
# 9        0                     0  0xf36990a2cb4d609e0a7d4f3bf884c0342d81fd3d
# 10     510               0.01377  0x13e2c5f84bce6ff7b9068313b21729dc8fd55d5a
# ...

# %%
x2 = data[l1[1]]
df2 = pd.DataFrame(x2)
df2
# Out:
#                    amount            amountBase  \
# 0     0.09433962264150943                0.0005
# 1    0.000662949474855733  0.000004972121061418
# 2                  65.589             0.3476217
# 3                  37.285              0.186425
# 4      17.936767815354248  0.009147751585830664
# 5      0.3133117699733889     0.028198059297605
# 6                      65                0.2015
# 7      17.992371795581843   0.09715880769614196
# 8          0.172492901917    0.0005347279959427
# 9                  85.093            0.46716057
# 10                     12               0.06588
# 11      9.084762544094696  0.049875346367079874
# 12      54.57184119822116   0.29959940817823416
# 13      8.837310653465016  0.026511931960395044
# 14    0.25005724512662825  0.001372814275745189
# 15                     19               0.10431
# 16                    0.6                 0.003
# 17                    100                   0.5
# ...

# %%
for i in l1:
    x_i = data[i]
    df_i = pd.DataFrame(x_i)
    df_i.to_csv('df_i.csv')
